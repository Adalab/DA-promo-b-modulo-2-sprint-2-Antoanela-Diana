# %% [markdown]
# `LIMPIEZA V`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sidetable as stb
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
pd.options.display.max_rows=None

# %%
df=pd.read_csv('../Datos/attacks_limpieza_III.csv')
df.head(2)
# Out:
#     case_number  year        type country        area  \
# 0    2018.06.25  2018     Boating     usa  California
# 1  2018.06.03.a  2018  Unprovoked  brazil  Pernambuco
#
#                       location  activity                    name  \
# 0  Oceanside, San Diego County  Paddling             Julie Wolfe
# 1        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva
#
#              time      species        siglo species_  \
# 0           18h00  White shark  siglo - XXI      NaN
# 1  Late afternoon  Tiger shark  siglo - XXI      NaN
#
#                                               injury  mes fatal_bien  \
# 0  No injury to occupant, outrigger canoe and pad...  Jun          N
# 1                                              FATAL  Jun          Y
#
#   genero_bien categorias_tiburones  edades
# 0           F                White    57.0
# 1           M                Tiger    18.0

# %%
df1= df.copy()

# %% [markdown]
# Es el momento de eliminar los nulos:
# 1. Reemplazad los valores nulos de la columna age por la media de la edad usando el método SimpleImputer.

# %%
imputer = SimpleImputer(strategy='mean', missing_values=np.nan)
imputer = imputer.fit(df1[['edades']])
df1['edades']=imputer.transform(df1[['edades']])

# %%
df1.edades.unique()
# Out:
# array([57.        , 18.        , 15.        , 32.        , 21.        ,
#        30.        , 60.        , 33.        , 19.        , 25.        ,
#        10.        , 55.        , 35.        , 20.        , 54.        ,
#        22.        , 31.        , 40.        , 37.        , 11.        ,
#        13.        , 34.        , 50.        , 46.        , 48.        ,
#        17.        , 28.        , 65.        , 58.        , 36.        ,
#        51.        , 61.        , 59.        , 42.        ,  6.        ,
#        27.        , 23.        , 29.        , 39.        , 24.        ,
#        12.        , 26.        , 43.        ,  9.        , 44.        ,
#        14.        , 62.        , 52.        , 38.        , 16.        ,
#        47.        , 63.        , 41.        , 53.        ,  7.        ,
#        45.        , 64.        ,  8.        , 56.        , 49.        ,
#        27.88903567,  5.        ])

# %%
df1.edades.isnull().sum()
# Out:
# 0

# %% [markdown]
# Reemplazad los valores nulos de la columna sex por la moda, usando el método SimpleImputer.💡 Pista 💡 La moda en este tipo de aproximación se indica como most_frequent.

# %%
imputer = SimpleImputer(strategy='most_frequent', missing_values=np.nan)
imputer = imputer.fit(df1[['genero_bien']])
df1['genero_bien']=imputer.transform(df1[['genero_bien']])

# %%
df1.genero_bien.isnull().sum()
# Out:
# 0

# %% [markdown]
# Reemplazad los valores nulos de la columna type por el valor más frecuente (la moda) con el método SimpleImputer.

# %%
imputer = SimpleImputer(strategy='most_frequent', missing_values=np.nan)
imputer = imputer.fit(df1[['type']])
df1['type']=imputer.transform(df1[['type']])

# %%
df1.type.isnull().sum()
# Out:
# 0

# %% [markdown]
# Utilizad el método KNN Imputer para reemplazar todos los valores nulos de las columnas numéricas.

# %%
numericas = df1.select_dtypes(include = np.number)
numericas
# Out:
#       year     edades
# 0     2018  57.000000
# 1     2018  18.000000
# 2     2018  15.000000
# 3     2018  32.000000
# 4     2018  21.000000
# 5     2018  30.000000
# 6     2018  60.000000
# 7     2018  32.000000
# 8     2018  33.000000
# 9     2018  19.000000
# 10    2018  25.000000
# 11    2018  10.000000
# 12    2018  25.000000
# 13    2018  18.000000
# 14    2018  55.000000
# 15    2018  35.000000
# 16    2018  20.000000
# 17    2017  54.000000
# 18    2017  25.000000
# 19    2017  25.000000
# 20    2017  22.000000
# 21    2017  31.000000
# 22    2017  15.000000
# 23    2017  54.000000
# 24    2017  40.000000
# 25    2017  33.000000
# 26    2017  18.000000
# 27    2017  35.000000
# 28    2017  37.000000
# 29    2017  11.000000
# 30    2017  25.000000
# 31    2017  13.000000
# 32    2017  34.000000
# 33    2017  10.000000
# 34    2017  40.000000
# 35    2017  50.000000
# 36    2017  46.000000
# 37    2017  13.000000
# 38    2017  48.000000
# 39    2017  32.000000
# ...

# %%
imputerKNN = KNNImputer(n_neighbors=5)
imputerKNN.fit(numericas)
numericas_knn= imputerKNN.transform(numericas)

# %%
df_knn_imputer = pd.DataFrame(numericas_knn, columns = numericas.columns)

# %%
df_knn_imputer.head()
# Out:
#      year  edades
# 0  2018.0    57.0
# 1  2018.0    18.0
# 2  2018.0    15.0
# 3  2018.0    32.0
# 4  2018.0    21.0

# %%
columnas_knn = df_knn_imputer.columns
columnas_knn
# Out:
# Index(['year', 'edades'], dtype='object')

# %% [markdown]
# Utilizad el método Iterative Imputer para reemplazar todos los valores nulos de las columnas numéricas.

# %%
imputer = IterativeImputer(n_nearest_features=None, imputation_order='ascending')
imputer.fit(numericas)
imputer.transform(numericas)
numericas_trans = pd.DataFrame(imputer.transform(numericas), columns = numericas.columns)
numericas_trans.head()
# Out:
#      year  edades
# 0  2018.0    57.0
# 1  2018.0    18.0
# 2  2018.0    15.0
# 3  2018.0    32.0
# 4  2018.0    21.0

# %%
numericas_trans.isnull().sum()
# Out:
# year      0
# edades    0
# dtype: int64

# %%
columnas = numericas_trans.columns
df.drop(columnas, axis = 1, inplace = True)
df[columnas] = numericas_trans[columnas]
df.head(2)
# Out:
#     case_number        type country        area                     location  \
# 0    2018.06.25     Boating     usa  California  Oceanside, San Diego County
# 1  2018.06.03.a  Unprovoked  brazil  Pernambuco        Piedade Beach, Recife
#
#    activity                    name            time      species        siglo  \
# 0  Paddling             Julie Wolfe           18h00  White shark  siglo - XXI
# 1  Swimming  Jose Ernesto da Silva   Late afternoon  Tiger shark  siglo - XXI
#
#   species_                                             injury  mes fatal_bien  \
# 0      NaN  No injury to occupant, outrigger canoe and pad...  Jun          N
# 1      NaN                                              FATAL  Jun          Y
#
#   genero_bien categorias_tiburones    year  edades
# 0           F                White  2018.0    57.0
# 1           M                Tiger  2018.0    18.0

# %%
nulos = pd.DataFrame((df.isnull().sum() * 100) / df.shape[0]).reset_index()
nulos.columns = ["columna", "porcentaje"]
nulos
# Out:
#                  columna  porcentaje
# 0            case_number    0.000000
# 1                   type    0.000000
# 2                country    0.598086
# 3                   area    2.751196
# 4               location    3.050239
# 5               activity    1.854067
# 6                   name    0.538278
# 7                   time    9.569378
# 8                species   10.167464
# 9                  siglo   10.167464
# 10              species_   97.368421
# 11                injury    0.478469
# 12                   mes    9.210526
# 13            fatal_bien    5.921053
# 14           genero_bien    0.000000
# 15  categorias_tiburones   59.928230
# 16                  year    0.000000
# 17                edades    0.000000

# %% [markdown]
# ¿Podríais explicar qué diferencia hay entre estos dos últimos métodos?

# %% [markdown]
# >IterativeImputer, que modela cada característica con valores perdidos como una función de otras variables, y utiliza esa estimación para la imputación. Lo hace de forma iterada: en cada paso, una columna
# se designa como salida(como variable que queremos predecir)  y las otras columnas se tratan como entradas X (como predictoras, es decir, las que nos van a ayudar a predecir
# los valores nulos de la columna que queremos). Se ajusta un regresor en (X, y). Se devuelven los resultados de la última ronda de imputación.
# El IterativeImputer utiliza los datos disponibles en otras columnas con el fin de estimar los valores nulos que se imputan o queremos quitar.
#
# >KNN IMPUTER solo lo podremos usar para variables numericas o de formato fecha.

# %% [markdown]
# Guardad el csv para seguir trabajando con el en los siguientes ejercicios de pair
